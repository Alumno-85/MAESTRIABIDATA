# %% [markdown]
# <a href="https://colab.research.google.com/github/Alumno-85/MAESTRIABIDATA/blob/main/M1B2T4_AI2_BernalFranklinI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Herramientas de Análisis**
#
# ---
# ---
#
# <!-- script html for image -->
#
# <center>
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Sw-ep1-logo.svg/1280px-Sw-ep1-logo.svg.png"  width="500" height="150"/>
#
#
# <br>
#
# Fuente de la imagen: [https://es.wikipedia.org](https://es.wikipedia.org/wiki/Star_Wars:_Episodio_I_-_La_amenaza_fantasma)
#
# </center>
#
# <br>

# %% [markdown]
# # **Índice**
#
# ---
# ---
#
# > [Herramientas de Análisis](#scrollTo=tW3jK_BDgjno&line=20&uniqifier=1)
# <br>
# >>
# >> [Preparación del Entorno](#scrollTo=5zZfGqOugjnr&line=3&uniqifier=1) \\
# >>   \\
# >> [Ejercicio 1](#scrollTo=1J4h6kTngjn5&line=1&uniqifier=1) \\
# >>

# %% [markdown]
# # Preparación del entorno
#
# Padawan! Cuando inicies sesión en Colab, prepara el entorno ejecutando el siguiente código.

# %%
if 'google.colab' in str(get_ipython()):
    # !git clone https://github.com/griu/mbdds_fc20.git /content/mbdds_fc20
    # !git -C /content/mbdds_fc20 pull
    # %cd /content/mbdds_fc20/Python
    # !python -m pip install -r requirementsColab.txt
# Out:
# Cloning into '/content/mbdds_fc20'...
# remote: Enumerating objects: 1014, done.
# remote: Counting objects: 100% (309/309), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 1014 (delta 160), reused 277 (delta 138), pack-reused 705
# Receiving objects: 100% (1014/1014), 16.89 MiB | 29.22 MiB/s, done.
# Resolving deltas: 100% (649/649), done.
# Already up to date.
# /content/mbdds_fc20/Python
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from -r requirementsColab.txt (line 1)) (0.13.1)
# Collecting beautifulsoup4==4.11.1 (from -r requirementsColab.txt (line 2))
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 2.8 MB/s eta 0:00:00
# Collecting eurostat==1.0.4 (from -r requirementsColab.txt (line 3))
#   Downloading eurostat-1.0.4-py3-none-any.whl (13 kB)
# Collecting world-bank-data==0.1.3 (from -r requirementsColab.txt (line 4))
#   Downloading world_bank_data-0.1.3.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apiclient==1.0.4 (from -r requirementsColab.txt (line 5))
#   Downloading apiclient-1.0.4.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: oauth2client==4.1.3 in /usr/local/lib/python3.10/dist-packages (from -r requirementsColab.txt (line 6)) (4.1.3)
# Collecting pymongo==3.11.0 (from -r requirementsColab.txt (line 7))
#   Downloading pymongo-3.11.0.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.7/771.7 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tweepy==3.6.0 (from -r requirementsColab.txt (line 8))
#   Downloading tweepy-3.6.0-py2.py3-none-any.whl (29 kB)
# Collecting facebook-business==9.0.3 (from -r requirementsColab.txt (line 9))
#   Downloading facebook_business-9.0.3-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from -r requirementsColab.txt (line 10)) (4.9.4)
# Collecting bs4==0.0.1 (from -r requirementsColab.txt (line 11))
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting selenium==3.141.0 (from -r requirementsColab.txt (line 12))
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.6/904.6 kB 22.8 MB/s eta 0:00:00
# Collecting httplib2==0.19.0 (from -r requirementsColab.txt (line 13))
#   Downloading httplib2-0.19.0-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.11.1->-r requirementsColab.txt (line 2)) (2.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from eurostat==1.0.4->-r requirementsColab.txt (line 3)) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from eurostat==1.0.4->-r requirementsColab.txt (line 3)) (2.31.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from world-bank-data==0.1.3->-r requirementsColab.txt (line 4)) (5.3.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from apiclient==1.0.4->-r requirementsColab.txt (line 5)) (2.0.7)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from apiclient==1.0.4->-r requirementsColab.txt (line 5)) (2024.2.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client==4.1.3->-r requirementsColab.txt (line 6)) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client==4.1.3->-r requirementsColab.txt (line 6)) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client==4.1.3->-r requirementsColab.txt (line 6)) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client==4.1.3->-r requirementsColab.txt (line 6)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tweepy==3.6.0->-r requirementsColab.txt (line 8)) (1.3.1)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.10/dist-packages (from tweepy==3.6.0->-r requirementsColab.txt (line 8)) (1.7.1)
# Collecting curlify>=2.1.0 (from facebook-business==9.0.3->-r requirementsColab.txt (line 9))
#   Downloading curlify-2.2.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pycountry>=19.8.18 (from facebook-business==9.0.3->-r requirementsColab.txt (line 9))
#   Downloading pycountry-23.12.11-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 36.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from facebook-business==9.0.3->-r requirementsColab.txt (line 9)) (3.9.5)
# Collecting pyparsing<3,>=2.4.2 (from httplib2==0.19.0->-r requirementsColab.txt (line 13))
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn->-r requirementsColab.txt (line 1)) (1.25.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn->-r requirementsColab.txt (line 1)) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirementsColab.txt (line 1)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirementsColab.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirementsColab.txt (line 1)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirementsColab.txt (line 1)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirementsColab.txt (line 1)) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirementsColab.txt (line 1)) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirementsColab.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->eurostat==1.0.4->-r requirementsColab.txt (line 3)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->eurostat==1.0.4->-r requirementsColab.txt (line 3)) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->eurostat==1.0.4->-r requirementsColab.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->eurostat==1.0.4->-r requirementsColab.txt (line 3)) (3.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->tweepy==3.6.0->-r requirementsColab.txt (line 8)) (3.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->facebook-business==9.0.3->-r requirementsColab.txt (line 9)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->facebook-business==9.0.3->-r requirementsColab.txt (line 9)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->facebook-business==9.0.3->-r requirementsColab.txt (line 9)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->facebook-business==9.0.3->-r requirementsColab.txt (line 9)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->facebook-business==9.0.3->-r requirementsColab.txt (line 9)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->facebook-business==9.0.3->-r requirementsColab.txt (line 9)) (4.0.3)
# Building wheels for collected packages: world-bank-data, apiclient, pymongo, bs4, curlify
#   Building wheel for world-bank-data (setup.py) ... done
#   Created wheel for world-bank-data: filename=world_bank_data-0.1.3-py3-none-any.whl size=11095 sha256=b3162f3eab58ff2bb8574fd66b1688d5c4e340cfc7c38c789f3ab349801bbe8e
#   Stored in directory: /root/.cache/pip/wheels/a3/ba/6f/7040ac2cf2d06ed4633fb9dd8bc2000a0cabf766b5a17d4d1a
#   Building wheel for apiclient (setup.py) ... done
#   Created wheel for apiclient: filename=apiclient-1.0.4-py3-none-any.whl size=5197 sha256=a6eaf312cfb748616d60c127cb8e29df8ac1ab0fb23c3b6dedf173d170dd18fe
#   Stored in directory: /root/.cache/pip/wheels/34/3d/05/8d65e9bcb2117ea3739b0fbf64d660a1cf06fa9def589ea306
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.11.0-cp310-cp310-linux_x86_64.whl size=493667 sha256=3c0b61cbd3c3d7aedb3643342651c9909a08d6b3e90cb74cee9185f44e66d049
#   Stored in directory: /root/.cache/pip/wheels/df/6e/99/27524029bf53fd025e0d44093d77e4fc0b27c6344acd6f3e86
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1255 sha256=e0c67efc32216a9fd3671e9016693b8098db9621f701ab5750c8bd48acb2c4a9
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
#   Building wheel for curlify (setup.py) ... done
#   Created wheel for curlify: filename=curlify-2.2.1-py3-none-any.whl size=2666 sha256=11d00907662517deb722c0db65ba134a5993f4aa246e434f21cc7713c5c57302
#   Stored in directory: /root/.cache/pip/wheels/01/e8/2f/e0e986ab1e8956d5ad10aabc059767c822d6114ed295a28dd5
# Successfully built world-bank-data apiclient pymongo bs4 curlify
# Installing collected packages: selenium, pyparsing, pymongo, pycountry, beautifulsoup4, apiclient, httplib2, curlify, bs4, world-bank-data, tweepy, facebook-business, eurostat
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
#   Attempting uninstall: httplib2
#     Found existing installation: httplib2 0.22.0
#     Uninstalling httplib2-0.22.0:
#       Successfully uninstalled httplib2-0.22.0
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 4.14.0
#     Uninstalling tweepy-4.14.0:
#       Successfully uninstalled tweepy-4.14.0
# Successfully installed apiclient-1.0.4 beautifulsoup4-4.11.1 bs4-0.0.1 curlify-2.2.1 eurostat-1.0.4 facebook-business-9.0.3 httplib2-0.19.0 pycountry-23.12.11 pymongo-3.11.0 pyparsing-2.4.7 selenium-3.141.0 tweepy-3.6.0 world-bank-data-0.1.3

# %% [markdown]
# # Ejercicio 1
#
# Para realizar el ejercicio cargamos los datos de *Especies* en STARWARS SWAPI y las librerías principales.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # para el estilo de graficos

entidades = ['planets','starships','vehicles','people','species']
entidades_df = {x: pd.read_pickle('www/' + x + '_df.pkl') for x in entidades}

# Datos principales
people_df = entidades_df['people'][["height","mass","birth_year","gender","homeworld"]].dropna()

people_df
# Out:
#                        height    mass  birth_year         gender  \
# name
# Luke Skywalker          172.0    77.0        19.0           male
# C-3PO                   167.0    75.0       112.0           none
# R2-D2                    96.0    32.0        33.0           none
# Darth Vader             202.0   136.0        41.9           male
# Leia Organa             150.0    49.0        19.0         female
# Owen Lars               178.0   120.0        52.0           male
# Beru Whitesun lars      165.0    75.0        47.0         female
# Biggs Darklighter       183.0    84.0        24.0           male
# Obi-Wan Kenobi          182.0    77.0        57.0           male
# Anakin Skywalker        188.0    84.0        41.9           male
# Chewbacca               228.0   112.0       200.0           male
# Han Solo                180.0    80.0        29.0           male
# Greedo                  173.0    74.0        44.0           male
# Jabba Desilijic Tiure   175.0  1358.0       600.0  hermaphrodite
# Wedge Antilles          170.0    77.0        21.0           male
# Yoda                     66.0    17.0       896.0           male
# Palpatine               170.0    75.0        82.0           male
# Boba Fett               183.0    78.2        31.5           male
# IG-88                   200.0   140.0        15.0           none
# Bossk                   190.0   113.0        53.0           male
# Lando Calrissian        177.0    79.0        31.0           male
# Lobot                   175.0    79.0        37.0           male
# Ackbar                  180.0    83.0        41.0           male
# Wicket Systri Warrick    88.0    20.0         8.0           male
# Qui-Gon Jinn            193.0    89.0        92.0           male
# Padmé Amidala           185.0    45.0        46.0         female
# Jar Jar Binks           196.0    66.0        52.0           male
# Darth Maul              175.0    80.0        54.0           male
# Ayla Secura             178.0    55.0        48.0         female
# Mace Windu              188.0    84.0        72.0           male
# Ki-Adi-Mundi            198.0    82.0        92.0           male
# Plo Koon                188.0    80.0        22.0           male
# Luminara Unduli         170.0    56.2        58.0         female
# Barriss Offee           166.0    50.0        40.0         female
# Dooku                   193.0    80.0       102.0           male
# Jango Fett              183.0    79.0        66.0           male
#
#                                               homeworld
# name
# Luke Skywalker          http://swapi.dev/api/planets/1/
# C-3PO                   http://swapi.dev/api/planets/1/
# R2-D2                   http://swapi.dev/api/planets/8/
# Darth Vader             http://swapi.dev/api/planets/1/
# Leia Organa             http://swapi.dev/api/planets/2/
# Owen Lars               http://swapi.dev/api/planets/1/
# Beru Whitesun lars      http://swapi.dev/api/planets/1/
# Biggs Darklighter       http://swapi.dev/api/planets/1/
# Obi-Wan Kenobi         http://swapi.dev/api/planets/20/
# Anakin Skywalker        http://swapi.dev/api/planets/1/
# Chewbacca              http://swapi.dev/api/planets/14/
# Han Solo               http://swapi.dev/api/planets/22/
# Greedo                 http://swapi.dev/api/planets/23/
# Jabba Desilijic Tiure  http://swapi.dev/api/planets/24/
# Wedge Antilles         http://swapi.dev/api/planets/22/
# Yoda                   http://swapi.dev/api/planets/28/
# Palpatine               http://swapi.dev/api/planets/8/
# Boba Fett              http://swapi.dev/api/planets/10/
# IG-88                  http://swapi.dev/api/planets/28/
# Bossk                  http://swapi.dev/api/planets/29/
# Lando Calrissian       http://swapi.dev/api/planets/30/
# Lobot                   http://swapi.dev/api/planets/6/
# Ackbar                 http://swapi.dev/api/planets/31/
# Wicket Systri Warrick   http://swapi.dev/api/planets/7/
# Qui-Gon Jinn           http://swapi.dev/api/planets/28/
# Padmé Amidala           http://swapi.dev/api/planets/8/
# Jar Jar Binks           http://swapi.dev/api/planets/8/
# Darth Maul             http://swapi.dev/api/planets/36/
# Ayla Secura            http://swapi.dev/api/planets/37/
# Mace Windu             http://swapi.dev/api/planets/42/
# Ki-Adi-Mundi           http://swapi.dev/api/planets/43/
# Plo Koon               http://swapi.dev/api/planets/49/
# Luminara Unduli        http://swapi.dev/api/planets/51/
# Barriss Offee          http://swapi.dev/api/planets/51/
# Dooku                  http://swapi.dev/api/planets/52/
# Jango Fett             http://swapi.dev/api/planets/53/

# %% [markdown]
# ## Ejercicio 1.1.
#
# Construye un gráfico de dispersión de los personajes donde se visualice: la altura (height), el peso (mass), la edad en años BBY (birth_year) y el género (gender). Para ello utiliza la función `sns.scatterplot()` de la librería seaborn. Aprovecha todos los parámetros: `x`, `y`, `size`, `hue` y `style` (consulta la ayuda de la función [.scatterplot()](https://seaborn.pydata.org/generated/seaborn.scatterplot.html).

# %%
# Solución:
plt.figure(figsize=(10, 6))
sns.scatterplot(data=people_df, x='height', y='mass', size='birth_year', hue='gender', style='gender', sizes=(20, 200))


plt.title('Personajes de Star Wars')
plt.xlabel('Altura')
plt.ylabel('Peso')
plt.legend(title='Género')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 1.2.
#
# Sobre el gráfico del ejercicio 1.1:
#
# - Pon título al gráfico y a los ejes x e y.
# - Modifica los límites del eje y para que aparezcan sólo personajes de menos de 150 Kg de peso.
# - Sitúa en el gráfico los nombres de "Darth Vader" y "Anakin Skywalker". ¿Cómo es posible tengan un peso y altura tan distintos si eran la misma persona?

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.3.
#
# Utiliza las *list comprehension* para calcular el cuadrado de los valores positivos de la siguiente lista:
#
# Muestra el resultado por pantalla.

# %%
val = [5, 6, -1, 2, -3, -7, 9, 1]

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.4.
#
# Construye un diccionario donde se identifique, mediante claves y valores, las siguientes características del personaje Yoda: "nombre", "altura", "peso", "edad" y "genero". Utiliza los datos de people_df.
#
# Muestra el diccionario por pantalla.

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.5.
#
# Calcula, a partir de los vectores numpy de altura y peso, vectores numpy que debe definir, el [índice de masa corporal (IMC)](https://es.wikipedia.org/wiki/%C3%8Dndice_de_masa_corporal) de los personajes de star wars contenidos en people_df:
#
# $IMC = \frac{peso}{altura^{2}}$ donde altura está en metros y el peso en kg.
#
# Muestra los datos por pantalla.

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.6.
#
# A partir del IMC que has calculado en el ejercicio 1.5. Construye un panel con dos histogramas:
#
# - Un histograma con toda la muestra
# - Un histograma seleccionando los valores con un IMC inferior a 100.

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.7.
#
# A partir del vector 1 y 2 que se definen a continuación contesta las siguientes preguntas:
#
# - Calcula el shape, ndim, size del vector1 y vector2
# - Explica cual es la diferencia entre vector1 y vector2 a partir de los que hayas observado

# %%
vector1 = np.hstack([altura,peso])
vector2 = np.vstack([altura,peso])

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.8.
#
# Crea una copia de people_df llamada personajes_df y renombra las columnas con su traducción al castellano.
#
# Muestra los 5 primeros registros del nuevo data frame con `.head()`.

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.9.
#
# Haz el mismo cálculo de IMC que has hecho en 1.5. pero directamente sobre el objeto personajes_df.
#
# Ordena el data frame de mayor a menor IMC y muestra el nombre e IMC de los personajes con IMC por encima de 30.
#
# > ¿Sabias que IMC por encima de 30 se considera obeso?

# %%
# Solución:

# %% [markdown]
# ## Ejercicio 1.10.
#
# Inserta un valor faltante en los valores de IMC que sean superiores a 100 y dibuja el histograma del IMC transformado con `.plot.hist()`.

# %%
# Solución:
